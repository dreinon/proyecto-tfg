# %% [markdown]
# # Revisió humana del control de degradació
#
# Aquest quadern mostra exactament 12 panells fixos de fragments musicals gravats a partir de quatre fonts MusicXML pròpies i CC0: dues mostres per cada cel·la `x2/x4 × clean/moderate/strong`. Cada panell conserva el sistema complet i amplia una ROI fixa amb la referència HR i la degradació LR corresponent. No carrega SMB, no calcula mètriques i no congela cap control automàticament.
#
# **No executeu aquest quadern rastrejat.** Obriu només la còpia ignorada `artifacts/phase2-degradation-preview/preview-working.ipynb` amb el kernel **Python 3 (score-super-resolution)**.
#
# Reviseu la continuïtat dels pentagrames, la geometria i llegibilitat de claus, armadures, compassos, notes, pliques, barres, silencis, alteracions, lligadures, articulacions, dinàmiques, text/lletra/dígits i l'exemple de gran pentagrama polifònic, així com les unions o marques espúries i que la severitat siga adequada per a l'avaluació controlada.

# %%
from score_super_resolution.degradation import DegradationPreviewSession

_working_copy_token = "__GENERATED_PHASE2_VISUAL_REVIEW_WORKING_COPY__"
if _working_copy_token.startswith("__GENERATED"):
    raise RuntimeError(
        "No executeu aquest quadern rastrejat; obriu "
        "artifacts/phase2-degradation-preview/preview-working.ipynb"
    )

review = DegradationPreviewSession()
review.summary()

# %% [markdown]
# ## Decisió científica
#
# Després d'inspeccionar els dotze panells, indiqueu la vostra identitat, seleccioneu **Accept** o **Reject**, escriviu una justificació concreta i premeu **Save scientific decision**. Aquesta és l'única acció que crea el registre de decisió ignorat per Git.

# %%
decision_controls = review.decision_widget()
