# %% [markdown]
# # Revisió humana del control de degradació
#
# Aquest quadern mostra el candidat `controlled-score-v2-candidate`: exactament 12 panells emparellats sobre els mateixos dos fragments i les mateixes ROI físiques en cada cel·la `x2/x4 × clean/moderate/strong`. HR és la referència d'alta resolució; LR és l'entrada degradada, ampliada només per a la visualització, i cada ROI cobreix la mateixa regió física en HR i LR. No carrega SMB, no calcula mètriques i no congela cap control automàticament.
#
# **No executeu aquest quadern rastrejat.** Obriu només la còpia ignorada `artifacts/phase2-degradation-preview/candidates/controlled-score-v2-candidate/preview-working.ipynb` amb el kernel **Python 3 (score-super-resolution)**.
#
# Compareu directament clean → moderate → strong per als mateixos fragments, primer en x2 i després en x4. Reviseu la continuïtat dels pentagrames i la recuperabilitat de noteheads, stems, beams, rests, accidentals, articulations, slurs/ties, dynamics i text/lyrics/digits. Busqueu unintended joins, separations o false marks, i valoreu si la separació x2/x4 és informativa: strong pot fer dubtosos els detalls fins, però ha de conservar estructura musical potencialment recuperable.

# %%
from score_super_resolution.degradation import DegradationPreviewSession

_working_copy_token = "__GENERATED_PHASE2_VISUAL_REVIEW_WORKING_COPY__"
if _working_copy_token.startswith("__GENERATED"):
    raise RuntimeError(
        "No executeu aquest quadern rastrejat; obriu "
        "artifacts/phase2-degradation-preview/candidates/"
        "controlled-score-v2-candidate/preview-working.ipynb"
    )

review = DegradationPreviewSession()
review.summary()

# %% [markdown]
# ## Decisió científica
#
# Després d'inspeccionar els dotze panells, indiqueu la vostra identitat, seleccioneu **Accept** o **Reject**, escriviu una justificació concreta i premeu **Save scientific decision**. Aquesta és l'única acció que crea el registre de decisió ignorat per Git.

# %%
decision_controls = review.decision_widget()
