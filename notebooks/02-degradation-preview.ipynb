# %% [markdown]
# # Revisió humana del control de degradació
#
# Aquest quadern mostra exactament 12 panells fixos creats únicament amb fixtures independents del projecte: dues mostres per cada cel·la `x2/x4 × clean/moderate/strong`. No carrega SMB, no calcula mètriques i no congela cap control automàticament.
#
# Reviseu la continuïtat dels pentagrames, la geometria i llegibilitat dels símbols menuts, els textos i dígits, les unions o marques espúries, i que la severitat siga adequada per a l'avaluació controlada.

# %%
from pathlib import Path

from score_super_resolution.degradation import DegradationPreviewSession

review = DegradationPreviewSession(Path.cwd())
review.summary()

# %% [markdown]
# ## Decisió científica
#
# Després d'inspeccionar els dotze panells, indiqueu la vostra identitat, seleccioneu **Accept** o **Reject**, escriviu una justificació concreta i premeu **Save scientific decision**. Aquesta és l'única acció que crea el registre de decisió ignorat per Git.

# %%
decision_controls = review.decision_widget()
